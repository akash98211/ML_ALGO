# %%
Nodes will expand until all leaves are pure

# %%
1. min_sample_leaf-default value 1-leaf node
2. min_sample_split-default value 2-branch node
3. max_depth-no of decision node(suppose depth =4, it will be continue upto 4 decision node)
4. criteron-gini, entropy(dafault gini)
CV-(cross validation)-if cv=5: training 80%-divide into 5
